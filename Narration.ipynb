# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv("../EK-annotations/EPIC_100_train.csv")
train_df.head()
# Out:
#   narration_id participant_id video_id narration_timestamp start_timestamp  \
# 0     P01_01_0            P01   P01_01        00:00:01.089     00:00:00.14
# 1     P01_01_1            P01   P01_01        00:00:02.629     00:00:04.37
# 2    P01_01_10            P01   P01_01        00:00:23.340     00:00:24.97
# 3   P01_01_100            P01   P01_01        00:07:57.919     00:07:59.75
# 4   P01_01_101            P01   P01_01        00:08:00.020     00:08:01.47
#
#   stop_timestamp  start_frame  stop_frame      narration     verb  verb_class  \
# 0    00:00:03.37            8         202      open door     open           3
# 1    00:00:06.17          262         370  turn on light  turn-on           6
# 2    00:00:26.20         1498        1572    open drawer     open           3
# 3    00:08:00.88        28785       28852       take cup     take           0
# 4    00:08:02.21        28888       28932  open cupboard     open           3
#
# ...

# %%
train_df["narration"].unique()
# Out:
# array(['open door', 'turn on light', 'open drawer', ...,
#        'pick up shredded paper from floor', 'put shredded paper in bin',
#        'pour out boiled water'], dtype=object)

# %%
train_df["narration"].nunique()
# Out:
# 15968

# %%
train_df.shape
# Out:
# (67217, 15)

# %%
participant_df = train_df[train_df["participant_id"]=="P01"]
video_df = participant_df[participant_df["video_id"]=="P01_102"]

# %%
video_df["narration"].unique()
# Out:
# array(['take knife and plate', 'move spatula and colander', 'take knife',
#        'wipe surface', 'move glass', 'move lid',
#        'throw dust into the bin', 'wipe hand', 'put down cloth',
#        'wash knife', 'pour washing up liquid into hand', 'wash hands',
#        'turn off tap', 'rinse hands', 'take rag', 'dry hands',
#        'put down rag', 'put down knife', 'take lid',
#        'put lid onto container', 'close lid', 'take container',
#        'open fridge', 'put container into fridge', 'close fridge',
#        'take fork', 'wash fork', 'put down fork', 'take plate',
#        'turn on tap', 'wash plate', 'open bin', 'take colander',
#        'put down plate', 'wash colander', 'put down colander',
#        'take spatula', 'rinse spatula', 'put down spatula', 'rinse fork',
#        'rinse knife', 'move orange skin into the bin', 'rinse colander',
#        'adjust tap', 'rinse plate', 'take wok',
#        'pour washing up liquid into wok', 'take sponge', 'put down wok',
# ...

# %%
video_df["narration"].value_counts()
# Out:
# narration
# wipe surface                 8
# turn off tap                 6
# rinse cloth                  5
# rinse wok                    4
# take knife                   4
#                             ..
# open bin                     1
# move spatula and colander    1
# put down colander            1
# take spatula                 1
# put down container           1
# Name: count, Length: 67, dtype: int64

# %%
video_df.head(15)
# Out:
#      narration_id participant_id video_id narration_timestamp start_timestamp  \
# 1896    P01_102_0            P01  P01_102        00:00:01.100     00:00:00.54
# 1897    P01_102_1            P01  P01_102        00:00:07.600     00:00:07.49
# 1898   P01_102_10            P01  P01_102        00:00:29.851     00:00:29.66
# 1899  P01_102_100            P01  P01_102        00:03:44.600     00:03:44.45
# 1900  P01_102_101            P01  P01_102        00:03:45.600     00:03:45.61
# 1901  P01_102_102            P01  P01_102        00:03:46.851     00:03:46.06
# 1902  P01_102_103            P01  P01_102        00:03:48.600     00:03:46.71
# 1903  P01_102_104            P01  P01_102        00:03:50.100     00:03:48.21
# 1904  P01_102_105            P01  P01_102        00:03:51.101     00:03:49.91
# 1905  P01_102_106            P01  P01_102        00:03:55.350     00:03:55.22
# 1906  P01_102_107            P01  P01_102        00:03:57.350     00:03:56.60
# ...
